# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Importing the dataset
data=pd.read_csv('mlr.csv')
# creating the features matrix
X=data.iloc[:, :-1].values
# creating the dependent variable matrix
y=data.iloc[:,-1].values

# %%
# Encoding the Categorical data: 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [3])], remainder='passthrough'
)
X=np.array(ct.fit_transform(X))

# %%
# Splitting the data into training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2, random_state=0)

# %% [markdown]
# - no need of scaling in MLR, because the coefficients handle the irregularities in scale of feature columns

# %% [markdown]
# Dummy variable trap: when the dummy variables have multicollinearity:
#
# - Multicollinearity is a problem in regression analysis because it occurs when independent variables are highly correlated, making it difficult for the model to isolate the individual effect of each predictor.
#
# - This instability leads to unreliable, high-variance coefficient estimates, inflated standard errors, and reduced statistical significance, hindering accurate model interpretation.
#
# - We don't have to do anything explicitly to avoid the dummy variable trap, the MLR class automatically handles it.

# %%
# Training the MLR model on the training set
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(X_train, y_train)

y_pred=mlr.predict(X_test)
np.set_printoptions(precision=2) #displays any decimal value upto 2 places
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)), 1))
# Out:
# [[178302.86 188000.  ]
#  [110894.8  107000.  ]
#  [145937.87 132000.  ]
#  [129093.97 124000.  ]
#  [160756.95 160000.  ]
#  [135618.09 141000.  ]]
